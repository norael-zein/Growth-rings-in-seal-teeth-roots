# %%
import cv2
import os
import matplotlib.pyplot as plt
import numpy as np
import pandas

# %%
points = []

def get_points(event, x, y, flags, param):
    if event == cv2.EVENT_LBUTTONDOWN:
        points.append((x, y))
        print(f"Point {len(points)}: x={x}, y={y}")

def rotate_point(x, y, M):
    x_new = M[0, 0]*x + M[0, 1]*y + M[0, 2]
    y_new = M[1, 0]*x + M[1, 1]*y + M[1, 2]
    return x_new, y_new

def create_samples(path, i):
    # points from clickcs
    I = cv2.imread(r'SplitImages/' + path)
    I_h, I_w = I.shape[:2]
    I = cv2.cvtColor(I, cv2.COLOR_BGR2RGB)
    scale = 0.5
    I_small = cv2.resize(I, (int(I_w*scale), int(I_h*scale)))

    cv2.namedWindow("Click points", cv2.WINDOW_NORMAL)
    cv2.resizeWindow("Click points", 1000, 700) 
    cv2.imshow("Click points", I_small)      
    cv2.setMouseCallback("Click points", get_points)

    while True:
        cv2.waitKey(1)
        if len(points) >= 2:
            break

    cv2.destroyAllWindows()
    print(f'Points: {points}')
    x_1 = points[0][0] * 2
    x_2 = points[1][0] * 2
    y_1 = points[0][1] * 2
    y_2 = points[1][1] * 2
    dx = x_2 - x_1
    dy = y_2 - y_1
    angle_rad = np.arctan2(dy, dx)
    angle_deg = np.degrees(angle_rad)
    center = (I_w // 2, I_h // 2)
    M = cv2.getRotationMatrix2D(center, angle_deg, 1.0)
    rotated = cv2.warpAffine(I, M, (I_w, I_h))
    p1r = rotate_point(x_1, y_1, M)
    p2r = rotate_point(x_2, y_2, M)

    y_min = int(min(p1r[1], p2r[1]) - 100)
    y_max = int(max(p1r[1], p2r[1]) + 100)
    x_min = int(min(p1r[0], p2r[0]))
    x_max = int(max(p1r[0], p2r[0]))
    y_min = max(y_min, 0)
    y_max = min(y_max, I_h)
    x_min = max(x_min, 0)
    x_max = min(x_max, I_w)
    cropped = rotated[y_min:y_max, x_min:x_max]
    
    f, a = plt.subplots(1, 3, figsize=(18, 6))
    a = a.ravel()
    a[0].imshow(I)
    a[0].plot([x_1, x_2], [y_1, y_2], 'red')
    a[1].imshow(rotated)
    a[1].plot([p1r[0], p2r[0]], [p1r[1], p2r[1]], 'red')
    a[2].imshow(cropped)
    plt.close(f)

    os.makedirs('NewImages', exist_ok=True)
    base, ext = os.path.splitext(path)
    #Split images will end up in NewImages folder
    f_name = os.path.join('NewImages', f"{base}_{i+1}{ext}")
    cv2.imwrite(f_name, cropped)
    print(f"Saved: {f_name}")

#Folder of interest = SplitImages
for path in os.listdir('SplitImages'):
    if path.lower().endswith(('.jpg', '.jpeg', '.png', '.bmp', '.tif', '.tiff')):
        print(f"\nBearbetar {path}")
        for i in range(3):
            create_samples(path, i)
            points = []
# Out:
# Bearbetar 2020-105 (1).jpg
# Point 1: x=302, y=91
# Point 2: x=38, y=182
# Points: [(302, 91), (38, 182)]
# Saved: NewImages\2020-105 (1)_1.jpg
# Point 1: x=330, y=163
# Point 2: x=84, y=335
# Points: [(330, 163), (84, 335)]
# Saved: NewImages\2020-105 (1)_2.jpg
# Point 1: x=367, y=202
# Point 2: x=164, y=447
# Points: [(367, 202), (164, 447)]
# Saved: NewImages\2020-105 (1)_3.jpg
#
# Bearbetar 2020-105 (2).jpg
# Point 1: x=195, y=153
# Point 2: x=581, y=113
# Points: [(195, 153), (581, 113)]
# Saved: NewImages\2020-105 (2)_1.jpg
# Point 1: x=204, y=204
# Point 2: x=584, y=188
# Points: [(204, 204), (584, 188)]
# Saved: NewImages\2020-105 (2)_2.jpg
# Point 1: x=200, y=250
# Point 2: x=613, y=271
# Points: [(200, 250), (613, 271)]
# Saved: NewImages\2020-105 (2)_3.jpg
#
# Bearbetar 2020-106 (1).jpg
# Point 1: x=452, y=101
# Point 2: x=549, y=108
# Points: [(452, 101), (549, 108)]
# Saved: NewImages\2020-106 (1)_1.jpg
# Point 1: x=441, y=165
# Point 2: x=547, y=167
# Points: [(441, 165), (547, 167)]
# Saved: NewImages\2020-106 (1)_2.jpg
# Point 1: x=431, y=218
# Point 2: x=538, y=225
# Points: [(431, 218), (538, 225)]
# Saved: NewImages\2020-106 (1)_3.jpg
#
# Bearbetar 2020-113.jpg
# Point 1: x=316, y=80
# Point 2: x=409, y=87
# Points: [(316, 80), (409, 87)]
# Saved: NewImages\2020-113_1.jpg
# Point 1: x=312, y=174
# Point 2: x=426, y=187
# Points: [(312, 174), (426, 187)]
# Saved: NewImages\2020-113_2.jpg
# Point 1: x=312, y=266
# Point 2: x=410, y=269
# Points: [(312, 266), (410, 269)]
# Saved: NewImages\2020-113_3.jpg
#
# Bearbetar 2020-115 (1).jpg
# Point 1: x=529, y=189
# Point 2: x=295, y=86
# Points: [(529, 189), (295, 86)]
# Saved: NewImages\2020-115 (1)_1.jpg
# Point 1: x=496, y=286
# Point 2: x=244, y=194
# Points: [(496, 286), (244, 194)]
# Saved: NewImages\2020-115 (1)_2.jpg
# Point 1: x=445, y=379
# Point 2: x=194, y=251
# Points: [(445, 379), (194, 251)]
# Saved: NewImages\2020-115 (1)_3.jpg
#
# Bearbetar 2020-117.jpg
# Point 1: x=274, y=205
# Point 2: x=124, y=206
# Points: [(274, 205), (124, 206)]
# Saved: NewImages\2020-117_1.jpg
# Point 1: x=282, y=137
# Point 2: x=131, y=148
# Points: [(282, 137), (131, 148)]
# Saved: NewImages\2020-117_2.jpg
# Point 1: x=281, y=90
# Point 2: x=138, y=97
# Points: [(281, 90), (138, 97)]
# Saved: NewImages\2020-117_3.jpg
#
# Bearbetar 2020-119.jpg
# Point 1: x=281, y=107
# Point 2: x=420, y=99
# Points: [(281, 107), (420, 99)]
# Saved: NewImages\2020-119_1.jpg
# Point 1: x=295, y=217
# Point 2: x=420, y=221
# Points: [(295, 217), (420, 221)]
# Saved: NewImages\2020-119_2.jpg
# Point 1: x=290, y=312
# Point 2: x=413, y=315
# Points: [(290, 312), (413, 315)]
# Saved: NewImages\2020-119_3.jpg
#
# Bearbetar 2020-121.jpg
# Point 1: x=340, y=195
# Point 2: x=450, y=252
# Points: [(340, 195), (450, 252)]
# Saved: NewImages\2020-121_1.jpg
# Point 1: x=379, y=118
# Point 2: x=481, y=161
# Points: [(379, 118), (481, 161)]
# Saved: NewImages\2020-121_2.jpg
# Point 1: x=402, y=54
# Point 2: x=508, y=111
# Points: [(402, 54), (508, 111)]
# Saved: NewImages\2020-121_3.jpg
#
# Bearbetar 2020-131.jpg
# Point 1: x=199, y=235
# Point 2: x=110, y=277
# Points: [(199, 235), (110, 277)]
# Saved: NewImages\2020-131_1.jpg
# Point 1: x=222, y=297
# Point 2: x=124, y=341
# Points: [(222, 297), (124, 341)]
# Saved: NewImages\2020-131_2.jpg
# Point 1: x=458, y=175
# Point 2: x=562, y=184
# Points: [(458, 175), (562, 184)]
# Saved: NewImages\2020-131_3.jpg
#
# Bearbetar 2020-132 (1).jpg
# Point 1: x=573, y=237
# Point 2: x=692, y=267
# Points: [(573, 237), (692, 267)]
# Saved: NewImages\2020-132 (1)_1.jpg
# Point 1: x=601, y=129
# Point 2: x=732, y=161
# Points: [(601, 129), (732, 161)]
# Saved: NewImages\2020-132 (1)_2.jpg
# Point 1: x=172, y=156
# Point 2: x=46, y=205
# Points: [(172, 156), (46, 205)]
# Saved: NewImages\2020-132 (1)_3.jpg
#
# Bearbetar 2020-88.jpg
# Point 1: x=227, y=153
# Point 2: x=138, y=180
# Points: [(227, 153), (138, 180)]
# Saved: NewImages\2020-88_1.jpg
# Point 1: x=258, y=218
# Point 2: x=157, y=266
# Points: [(258, 218), (157, 266)]
# Saved: NewImages\2020-88_2.jpg
# Point 1: x=282, y=279
# Point 2: x=182, y=322
# Points: [(282, 279), (182, 322)]
# Saved: NewImages\2020-88_3.jpg
#
# Bearbetar 2020-89.jpg
# Point 1: x=242, y=146
# Point 2: x=403, y=164
# Points: [(242, 146), (403, 164)]
# Saved: NewImages\2020-89_1.jpg
# Point 1: x=239, y=225
# Point 2: x=382, y=238
# Points: [(239, 225), (382, 238)]
# Saved: NewImages\2020-89_2.jpg
# Point 1: x=214, y=301
# Point 2: x=372, y=321
# Points: [(214, 301), (372, 321)]
# Saved: NewImages\2020-89_3.jpg
#
# Bearbetar 2020-91.jpg
# Point 1: x=242, y=125
# Point 2: x=140, y=158
# Points: [(242, 125), (140, 158)]
# Saved: NewImages\2020-91_1.jpg
# Point 1: x=272, y=170
# Point 2: x=162, y=232
# Points: [(272, 170), (162, 232)]
# Saved: NewImages\2020-91_2.jpg
# Point 1: x=306, y=267
# Point 2: x=206, y=333
# Points: [(306, 267), (206, 333)]
# Saved: NewImages\2020-91_3.jpg
#
# Bearbetar 2020-93.jpg
# Point 1: x=199, y=130
# Point 2: x=118, y=199
# Points: [(199, 130), (118, 199)]
# Saved: NewImages\2020-93_1.jpg
# Point 1: x=253, y=183
# Point 2: x=169, y=252
# Points: [(253, 183), (169, 252)]
# Saved: NewImages\2020-93_2.jpg
# Point 1: x=294, y=239
# Point 2: x=208, y=315
# Points: [(294, 239), (208, 315)]
# Saved: NewImages\2020-93_3.jpg
#
# Bearbetar 2020-96.jpg
# Point 1: x=351, y=182
# Point 2: x=230, y=187
# Points: [(351, 182), (230, 187)]
# Saved: NewImages\2020-96_1.jpg
# Point 1: x=351, y=137
# Point 2: x=239, y=144
# Points: [(351, 137), (239, 144)]
# Saved: NewImages\2020-96_2.jpg
# Point 1: x=354, y=89
# Point 2: x=246, y=83
# Points: [(354, 89), (246, 83)]
# Saved: NewImages\2020-96_3.jpg
#
# Bearbetar 2020-97.jpg
# Point 1: x=210, y=192
# Point 2: x=125, y=234
# Points: [(210, 192), (125, 234)]
# Saved: NewImages\2020-97_1.jpg
# Point 1: x=230, y=242
# Point 2: x=147, y=282
# Points: [(230, 242), (147, 282)]
# Saved: NewImages\2020-97_2.jpg
# Point 1: x=255, y=282
# Point 2: x=172, y=333
# Points: [(255, 282), (172, 333)]
# Saved: NewImages\2020-97_3.jpg
#
# Bearbetar 2020-99.jpg
# Point 1: x=346, y=129
# Point 2: x=539, y=103
# Points: [(346, 129), (539, 103)]
# Saved: NewImages\2020-99_1.jpg
# Point 1: x=351, y=218
# Point 2: x=577, y=211
# Points: [(351, 218), (577, 211)]
# Saved: NewImages\2020-99_2.jpg
# Point 1: x=344, y=317
# Point 2: x=556, y=346
# Points: [(344, 317), (556, 346)]
# Saved: NewImages\2020-99_3.jpg
#
# Bearbetar A2019-05378.jpg
# Point 1: x=496, y=132
# Point 2: x=115, y=234
# Points: [(496, 132), (115, 234)]
# Saved: NewImages\A2019-05378_1.jpg
# Point 1: x=567, y=288
# Point 2: x=124, y=420
# Points: [(567, 288), (124, 420)]
# Saved: NewImages\A2019-05378_2.jpg
# Point 1: x=586, y=424
# Point 2: x=180, y=556
# Points: [(586, 424), (180, 556)]
# Saved: NewImages\A2019-05378_3.jpg
#
# Bearbetar B2022-03609 (1).jpg
# Point 1: x=434, y=137
# Point 2: x=576, y=160
# Points: [(434, 137), (576, 160)]
# Saved: NewImages\B2022-03609 (1)_1.jpg
# Point 1: x=418, y=201
# Point 2: x=564, y=237
# Points: [(418, 201), (564, 237)]
# Saved: NewImages\B2022-03609 (1)_2.jpg
# Point 1: x=393, y=290
# Point 2: x=527, y=341
# Points: [(393, 290), (527, 341)]
# Saved: NewImages\B2022-03609 (1)_3.jpg
#
# Bearbetar B2023-03383.jpg
# Point 1: x=1045, y=588
# Point 2: x=797, y=331
# Points: [(1045, 588), (797, 331)]
# Saved: NewImages\B2023-03383_1.jpg
# Point 1: x=966, y=818
# Point 2: x=706, y=547
# Points: [(966, 818), (706, 547)]
# Saved: NewImages\B2023-03383_2.jpg
# Point 1: x=925, y=1020
# Point 2: x=624, y=769
# Points: [(925, 1020), (624, 769)]
# Saved: NewImages\B2023-03383_3.jpg
#
# Bearbetar B2024-00008 (1).jpg
# Point 1: x=286, y=204
# Point 2: x=361, y=204
# Points: [(286, 204), (361, 204)]
# Saved: NewImages\B2024-00008 (1)_1.jpg
# Point 1: x=287, y=261
# Point 2: x=345, y=261
# Points: [(287, 261), (345, 261)]
# Saved: NewImages\B2024-00008 (1)_2.jpg
# Point 1: x=282, y=343
# Point 2: x=358, y=342
# Points: [(282, 343), (358, 342)]
# Saved: NewImages\B2024-00008 (1)_3.jpg
#
# Bearbetar B2024-01864 (1).jpg
# Point 1: x=807, y=214
# Point 2: x=356, y=262
# Points: [(807, 214), (356, 262)]
# Saved: NewImages\B2024-01864 (1)_1.jpg
# Point 1: x=777, y=385
# Point 2: x=359, y=420
# Points: [(777, 385), (359, 420)]
# Saved: NewImages\B2024-01864 (1)_2.jpg
# Point 1: x=754, y=556
# Point 2: x=359, y=576
# Points: [(754, 556), (359, 576)]
# Saved: NewImages\B2024-01864 (1)_3.jpg
#
# Bearbetar B2024-03884 (1).jpg
# Point 1: x=420, y=379
# Point 2: x=318, y=423
# Points: [(420, 379), (318, 423)]
# Saved: NewImages\B2024-03884 (1)_1.jpg
# Point 1: x=362, y=251
# Point 2: x=258, y=293
# Points: [(362, 251), (258, 293)]
# Saved: NewImages\B2024-03884 (1)_2.jpg
# Point 1: x=321, y=123
# Point 2: x=213, y=179
# Points: [(321, 123), (213, 179)]
# Saved: NewImages\B2024-03884 (1)_3.jpg
#
# Bearbetar B2024-04589 (1).jpg
# Point 1: x=366, y=301
# Point 2: x=656, y=297
# Points: [(366, 301), (656, 297)]
# Saved: NewImages\B2024-04589 (1)_1.jpg
# Point 1: x=349, y=508
# Point 2: x=638, y=512
# Points: [(349, 508), (638, 512)]
# Saved: NewImages\B2024-04589 (1)_2.jpg
# Point 1: x=346, y=667
# Point 2: x=635, y=683
# Points: [(346, 667), (635, 683)]
# Saved: NewImages\B2024-04589 (1)_3.jpg
#
# Bearbetar B2024-04589 (2).JPG
# Point 1: x=1063, y=927
# Point 2: x=1246, y=994
# Points: [(1063, 927), (1246, 994)]
# Saved: NewImages\B2024-04589 (2)_1.JPG
# Point 1: x=1022, y=1218
# Point 2: x=1184, y=1302
# Points: [(1022, 1218), (1184, 1302)]
# Saved: NewImages\B2024-04589 (2)_2.JPG
# Point 1: x=410, y=996
# Point 2: x=189, y=1123
# Points: [(410, 996), (189, 1123)]
# Saved: NewImages\B2024-04589 (2)_3.JPG
#
# Bearbetar B2024-04767 (1).jpg
# Point 1: x=222, y=389
# Point 2: x=783, y=257
# Points: [(222, 389), (783, 257)]
# Saved: NewImages\B2024-04767 (1)_1.jpg
# Point 1: x=226, y=563
# Point 2: x=791, y=453
# Points: [(226, 563), (791, 453)]
# Saved: NewImages\B2024-04767 (1)_2.jpg
# Point 1: x=343, y=750
# Point 2: x=838, y=679
# Points: [(343, 750), (838, 679)]
# Saved: NewImages\B2024-04767 (1)_3.jpg
#
# Bearbetar B2024-04995.jpg
# Point 1: x=610, y=269
# Point 2: x=504, y=272
# Points: [(610, 269), (504, 272)]
# Saved: NewImages\B2024-04995_1.jpg
# Point 1: x=621, y=361
# Point 2: x=507, y=373
# Points: [(621, 361), (507, 373)]
# Saved: NewImages\B2024-04995_2.jpg
# Point 1: x=614, y=494
# Point 2: x=499, y=497
# Points: [(614, 494), (499, 497)]
# Saved: NewImages\B2024-04995_3.jpg
#
# Bearbetar B2024-05143 (1).jpg
# Point 1: x=412, y=208
# Point 2: x=655, y=193
# Points: [(412, 208), (655, 193)]
# Saved: NewImages\B2024-05143 (1)_1.jpg
# Point 1: x=414, y=413
# Point 2: x=640, y=404
# Points: [(414, 413), (640, 404)]
# Saved: NewImages\B2024-05143 (1)_2.jpg
# Point 1: x=425, y=600
# Point 2: x=650, y=597
# Points: [(425, 600), (650, 597)]
# Saved: NewImages\B2024-05143 (1)_3.jpg
#
# Bearbetar B2024-05145.JPG
# Point 1: x=644, y=732
# Point 2: x=534, y=645
# Points: [(644, 732), (534, 645)]
# Saved: NewImages\B2024-05145_1.JPG
# Point 1: x=612, y=899
# Point 2: x=493, y=832
# Points: [(612, 899), (493, 832)]
# Saved: NewImages\B2024-05145_2.JPG
# Point 1: x=578, y=1054
# Point 2: x=476, y=988
# Points: [(578, 1054), (476, 988)]
# Saved: NewImages\B2024-05145_3.JPG
#
# Bearbetar B2024-05147 (1).JPG
# Point 1: x=644, y=662
# Point 2: x=854, y=717
# Points: [(644, 662), (854, 717)]
# Saved: NewImages\B2024-05147 (1)_1.JPG
# Point 1: x=615, y=948
# Point 2: x=797, y=1051
# Points: [(615, 948), (797, 1051)]
# Saved: NewImages\B2024-05147 (1)_2.JPG
# Point 1: x=559, y=1169
# Point 2: x=753, y=1273
# Points: [(559, 1169), (753, 1273)]
# Saved: NewImages\B2024-05147 (1)_3.JPG
#
# Bearbetar B2024-05147 (2).JPG
# Point 1: x=739, y=714
# Point 2: x=916, y=815
# Points: [(739, 714), (916, 815)]
# Saved: NewImages\B2024-05147 (2)_1.JPG
# Point 1: x=703, y=927
# Point 2: x=894, y=1066
# Points: [(703, 927), (894, 1066)]
# Saved: NewImages\B2024-05147 (2)_2.JPG
# Point 1: x=794, y=539
# Point 2: x=968, y=668
# Points: [(794, 539), (968, 668)]
# Saved: NewImages\B2024-05147 (2)_3.JPG
#
# Bearbetar B2024-06223 (1).JPG
# Point 1: x=357, y=783
# Point 2: x=983, y=708
# Points: [(357, 783), (983, 708)]
# Saved: NewImages\B2024-06223 (1)_1.JPG
# Point 1: x=348, y=1054
# Point 2: x=996, y=965
# Points: [(348, 1054), (996, 965)]
# Saved: NewImages\B2024-06223 (1)_2.JPG
# Point 1: x=298, y=1325
# Point 2: x=999, y=1302
# Points: [(298, 1325), (999, 1302)]
# Saved: NewImages\B2024-06223 (1)_3.JPG
#
# Bearbetar B2024-6223 (2).JPG
# Point 1: x=1388, y=1146
# Point 2: x=785, y=1164
# Points: [(1388, 1146), (785, 1164)]
# Saved: NewImages\B2024-6223 (2)_1.JPG
# Point 1: x=213, y=930
# Point 2: x=759, y=1135
# Points: [(213, 930), (759, 1135)]
# Saved: NewImages\B2024-6223 (2)_2.JPG
# Point 1: x=257, y=605
# Point 2: x=756, y=582
# Points: [(257, 605), (756, 582)]
# Saved: NewImages\B2024-6223 (2)_3.JPG
#
# Bearbetar B2025-00013 (1).jpg
# Point 1: x=690, y=278
# Point 2: x=392, y=336
# Points: [(690, 278), (392, 336)]
# Saved: NewImages\B2025-00013 (1)_1.jpg
# Point 1: x=696, y=427
# Point 2: x=390, y=477
# Points: [(696, 427), (390, 477)]
# Saved: NewImages\B2025-00013 (1)_2.jpg
# Point 1: x=716, y=611
# Point 2: x=381, y=658
# Points: [(716, 611), (381, 658)]
# Saved: NewImages\B2025-00013 (1)_3.jpg
#
# Bearbetar B2025-00052 (1).jpg
# Point 1: x=436, y=467
# Point 2: x=803, y=446
# Points: [(436, 467), (803, 446)]
# Saved: NewImages\B2025-00052 (1)_1.jpg
# Point 1: x=443, y=626
# Point 2: x=799, y=607
# Points: [(443, 626), (799, 607)]
# Saved: NewImages\B2025-00052 (1)_2.jpg
# Point 1: x=368, y=186
# Point 2: x=794, y=143
# Points: [(368, 186), (794, 143)]
# Saved: NewImages\B2025-00052 (1)_3.jpg
#
# Bearbetar C2003-05275a.jpg
# Point 1: x=217, y=522
# Point 2: x=316, y=323
# Points: [(217, 522), (316, 323)]
# Saved: NewImages\C2003-05275a_1.jpg
# Point 1: x=273, y=598
# Point 2: x=366, y=380
# Points: [(273, 598), (366, 380)]
# Saved: NewImages\C2003-05275a_2.jpg
# Point 1: x=342, y=679
# Point 2: x=419, y=500
# Points: [(342, 679), (419, 500)]
# Saved: NewImages\C2003-05275a_3.jpg
#
# Bearbetar C2009-10158 (1).jpg
# Point 1: x=217, y=170
# Point 2: x=271, y=161
# Points: [(217, 170), (271, 161)]
# Saved: NewImages\C2009-10158 (1)_1.jpg
# Point 1: x=223, y=277
# Point 2: x=281, y=276
# Points: [(223, 277), (281, 276)]
# Saved: NewImages\C2009-10158 (1)_2.jpg
# Point 1: x=228, y=363
# Point 2: x=283, y=357
# Points: [(228, 363), (283, 357)]
# Saved: NewImages\C2009-10158 (1)_3.jpg
