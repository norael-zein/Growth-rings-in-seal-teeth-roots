# %%
sys.path.append("../dataloaders")

# %%
import torch
import torch.nn as nn
import torch.optim as optim
import torchvision.models as models
from torchvision.models import ResNet18_Weights
from data_loader_cropping_padding import CroppedPaddedDataset
from torch.utils.data import random_split, DataLoader
import matplotlib.pyplot as plt
import sys

# %%
dataset = CroppedPaddedDataset("../labels.csv", "../images")
# Out:
# Image width 400 and height 200
# Found 402 valid samples

# %%
class CNNRegressor(nn.Module):
    def __init__(self):
        super().__init__()
        self.features = nn.Sequential(
            nn.Conv2d(3, 16, 3, padding=1),
            nn.ReLU(),
            nn.MaxPool2d(2),

            nn.Conv2d(16, 32, 3, padding=1),
            nn.ReLU(),
            nn.MaxPool2d(2),

            nn.Conv2d(32, 64, 3, padding=1),  
            nn.ReLU(),
            nn.MaxPool2d(2),
        )
        self.gap = nn.AdaptiveAvgPool2d((1, 1))
        self.regressor = nn.Sequential(
            nn.Flatten(),
            nn.Dropout(0.1),        
            nn.Linear(64, 32),
            nn.ReLU(),
            nn.Linear(32, 1),
        )

    def forward(self, x):
        x = self.features(x)
        x = self.gap(x)
        x = self.regressor(x)
        return x

# %%
#Training and validation data
val_split = 0.2  
n_total = len(dataset)
n_val = int(n_total * val_split)
n_train = n_total - n_val

train_set, val_set = random_split(dataset, [n_train, n_val])

train_loader = DataLoader(train_set, batch_size=32, shuffle=True)
val_loader = DataLoader(val_set, batch_size=32, shuffle=False)

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print("Using device:", device)

model = CNNRegressor().to(device)
criterion = nn.MSELoss()
optimizer = optim.Adam(model.parameters(), lr=5e-4, weight_decay=1e-4)
# Out:
# Using device: cpu

# %%
num_epochs = 50
train_mse_list = []
val_mse_list = []
val_mae_list = []

for epoch in range(num_epochs):
    #Training
    model.train()
    running_loss = 0.0
    n = 0

    for imgs, labels, names in train_loader:   
        imgs = imgs.to(device)
        labels = labels.float().view(-1, 1).to(device)

        optimizer.zero_grad()
        outputs = model(imgs)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()

        batch_size = imgs.size(0)
        running_loss += loss.item() * imgs.size(0)
        n += batch_size

    print(f"Epoch {epoch+1}/{num_epochs} - Train MSE: {running_loss / n:.4f}")

    #Validation
    model.eval()
    val_loss = 0.0
    val_mae = 0.0
    n_val = 0

    with torch.no_grad():
        for imgs, labels, names in val_loader:
            imgs = imgs.to(device)
            labels = labels.float().view(-1, 1).to(device)

            outputs = model(imgs)

            #MSE 
            loss = criterion(outputs, labels)
            val_loss += loss.item() * imgs.size(0)

            #MAE 
            val_mae += torch.abs(outputs - labels).sum().item()

            n_val += imgs.size(0)

    train_mse = running_loss / n
    val_mse = val_loss / n_val
    val_mae_epoch = val_mae / n_val

    train_mse_list.append(train_mse)
    val_mse_list.append(val_mse)
    val_mae_list.append(val_mae_epoch)

    print(f"Val MSE: {val_loss / n_val:.4f} | Val MAE: {val_mae / n_val:.4f}")
# Out:
# Epoch 1/50 - Train MSE: 69.8664
# Val MSE: 53.6519 | Val MAE: 5.3680
# Epoch 2/50 - Train MSE: 65.1155
# Val MSE: 44.8021 | Val MAE: 4.5057
# Epoch 3/50 - Train MSE: 49.4978
# Val MSE: 25.4163 | Val MAE: 3.1298
# Epoch 4/50 - Train MSE: 30.9454
# Val MSE: 27.1996 | Val MAE: 4.1539
# Epoch 5/50 - Train MSE: 30.0274
# Val MSE: 23.0145 | Val MAE: 3.4175
# Epoch 6/50 - Train MSE: 29.2893
# Val MSE: 22.8774 | Val MAE: 3.3651
# Epoch 7/50 - Train MSE: 29.6445
# Val MSE: 23.2168 | Val MAE: 3.5296
# Epoch 8/50 - Train MSE: 29.0370
# Val MSE: 22.7811 | Val MAE: 3.3744
# Epoch 9/50 - Train MSE: 29.2527
# Val MSE: 22.7617 | Val MAE: 3.3777
# Epoch 10/50 - Train MSE: 29.4900
# Val MSE: 22.7598 | Val MAE: 3.3828
# Val MSE: 20.7578 | Val MAE: 3.0740
# Epoch 40/50 - Train MSE: 25.9363
# Val MSE: 20.5885 | Val MAE: 3.0153
# Epoch 41/50 - Train MSE: 24.7592
# Val MSE: 20.8534 | Val MAE: 3.1398
# Epoch 42/50 - Train MSE: 24.5336
# Val MSE: 20.2502 | Val MAE: 3.0014
# Epoch 43/50 - Train MSE: 25.5216
# Val MSE: 20.0148 | Val MAE: 2.9181
# Epoch 44/50 - Train MSE: 25.1906
# Val MSE: 20.5522 | Val MAE: 3.1095
# Epoch 45/50 - Train MSE: 25.5344
# Val MSE: 19.7132 | Val MAE: 2.8340
# Epoch 46/50 - Train MSE: 24.5386
# Val MSE: 19.9640 | Val MAE: 2.8609
# Epoch 47/50 - Train MSE: 23.8243
# Val MSE: 20.6524 | Val MAE: 3.1409
# Epoch 48/50 - Train MSE: 24.5938
# Val MSE: 19.6720 | Val MAE: 2.7888
# Epoch 49/50 - Train MSE: 24.3130
# Val MSE: 19.6130 | Val MAE: 2.7682
# Epoch 50/50 - Train MSE: 23.1257
# Val MSE: 19.6400 | Val MAE: 2.8830

# %%
epochs = range(1, num_epochs + 1)

plt.plot(epochs, train_mse_list, label='Train MSE')
plt.plot(epochs, val_mse_list, label='Val MSE')
plt.xlabel('Epoch')
plt.ylabel('Error')
plt.legend()
plt.title('Training and Validation MSE')
plt.show()

# %%
epochs = range(1, num_epochs + 1)

plt.plot(epochs, val_mae_list, label='Val MAE')
plt.xlabel('Epoch')
plt.ylabel('Error')
plt.legend()
plt.title('Validation MAE')
plt.show()

# %%
class ResNetRegressor(nn.Module):
    def __init__(self):
        super().__init__()
        #Resnet18
        self.backbone = models.resnet18(weights=ResNet18_Weights.DEFAULT)
        
        #Last layer with regression
        in_features = self.backbone.fc.in_features
        self.backbone.fc = nn.Linear(in_features, 1)

    def forward(self, x):
        return self.backbone(x)

model = ResNetRegressor().to(device)

# %%
criterion = nn.SmoothL1Loss(beta=1.0)  #Huber-loss

optimizer = optim.Adam(model.parameters(), lr=1e-4, weight_decay=1e-4)

scheduler = optim.lr_scheduler.ReduceLROnPlateau(
    optimizer, mode='min', factor=0.5, patience=5, verbose=True
)

num_epochs = 50  

train_mse_list = []
val_mse_list = []
val_mae_list = []
# Out:
# C:\Users\norae\AppData\Roaming\Python\Python312\site-packages\torch\optim\lr_scheduler.py:62: UserWarning: The verbose parameter is deprecated. Please use get_last_lr() to access the learning rate.
#   warnings.warn(

# %%
#Train ResNet regressor
for epoch in range(num_epochs):
    #Train
    model.train()
    running_mse = 0.0
    n_train = 0

    for imgs, labels, names in train_loader:
        imgs = imgs.to(device)
        labels = labels.float().view(-1, 1).to(device)

        optimizer.zero_grad()
        outputs = model(imgs)

        loss = criterion(outputs, labels)   #SmoothL1Loss
        loss.backward()
        optimizer.step()

        #MSE
        mse_batch = torch.mean((outputs - labels) ** 2).item()
        batch_size = imgs.size(0)
        running_mse += mse_batch * batch_size
        n_train += batch_size

    train_mse_epoch = running_mse / n_train
    train_mse_list.append(train_mse_epoch)

    #Validation
    model.eval()
    val_mse = 0.0
    val_mae = 0.0
    n_val = 0

    with torch.no_grad():
        for imgs, labels, names in val_loader:
            imgs = imgs.to(device)
            labels = labels.float().view(-1, 1).to(device)

            outputs = model(imgs)

            mse_batch = torch.mean((outputs - labels) ** 2).item()
            mae_batch = torch.mean(torch.abs(outputs - labels)).item()
            batch_size = imgs.size(0)

            val_mse += mse_batch * batch_size
            val_mae += mae_batch * batch_size
            n_val += batch_size

    val_mse_epoch = val_mse / n_val
    val_mae_epoch = val_mae / n_val

    val_mse_list.append(val_mse_epoch)
    val_mae_list.append(val_mae_epoch)

    scheduler.step(val_mae_epoch)

    print(
        f"Epoch {epoch+1}/{num_epochs} - "
        f"Train MSE: {train_mse_epoch:.3f} - "
        f"Val MSE: {val_mse_epoch:.3f} - "
        f"Val MAE: {val_mae_epoch:.3f}"
    )
# Out:
# Epoch 1/50 - Train MSE: 62.721 - Val MSE: 62.352 - Val MAE: 6.409
# Epoch 2/50 - Train MSE: 38.617 - Val MSE: 41.488 - Val MAE: 4.830
# Epoch 3/50 - Train MSE: 27.040 - Val MSE: 28.003 - Val MAE: 3.486
# Epoch 4/50 - Train MSE: 22.214 - Val MSE: 20.915 - Val MAE: 2.638
# Epoch 5/50 - Train MSE: 17.864 - Val MSE: 14.297 - Val MAE: 1.957
# Epoch 6/50 - Train MSE: 14.605 - Val MSE: 14.213 - Val MAE: 1.959
# Epoch 7/50 - Train MSE: 11.630 - Val MSE: 16.406 - Val MAE: 2.261
# Epoch 8/50 - Train MSE: 10.517 - Val MSE: 16.703 - Val MAE: 2.178
# Epoch 9/50 - Train MSE: 8.022 - Val MSE: 15.151 - Val MAE: 1.871
# Epoch 10/50 - Train MSE: 6.820 - Val MSE: 12.815 - Val MAE: 1.741
# Epoch 11/50 - Train MSE: 5.217 - Val MSE: 10.572 - Val MAE: 1.703
# Epoch 12/50 - Train MSE: 7.969 - Val MSE: 13.220 - Val MAE: 1.795
# Epoch 13/50 - Train MSE: 7.725 - Val MSE: 10.850 - Val MAE: 1.826
# Epoch 14/50 - Train MSE: 6.965 - Val MSE: 11.850 - Val MAE: 1.900
# Epoch 15/50 - Train MSE: 9.183 - Val MSE: 12.782 - Val MAE: 1.812
# Epoch 16/50 - Train MSE: 7.464 - Val MSE: 10.527 - Val MAE: 1.910
# Epoch 17/50 - Train MSE: 5.302 - Val MSE: 10.385 - Val MAE: 1.614
# Epoch 18/50 - Train MSE: 3.138 - Val MSE: 11.618 - Val MAE: 1.755
# Epoch 19/50 - Train MSE: 2.808 - Val MSE: 12.059 - Val MAE: 1.945
# Epoch 20/50 - Train MSE: 2.441 - Val MSE: 11.040 - Val MAE: 1.746
# Epoch 21/50 - Train MSE: 3.362 - Val MSE: 9.795 - Val MAE: 1.776
# Epoch 22/50 - Train MSE: 2.763 - Val MSE: 8.908 - Val MAE: 1.733
# Epoch 23/50 - Train MSE: 3.889 - Val MSE: 9.915 - Val MAE: 1.762
# Epoch 24/50 - Train MSE: 2.364 - Val MSE: 11.055 - Val MAE: 1.671
# Epoch 25/50 - Train MSE: 4.509 - Val MSE: 9.856 - Val MAE: 1.676
# Epoch 26/50 - Train MSE: 3.421 - Val MSE: 8.216 - Val MAE: 1.530
# Epoch 27/50 - Train MSE: 5.039 - Val MSE: 7.997 - Val MAE: 1.484
# Epoch 28/50 - Train MSE: 3.554 - Val MSE: 8.140 - Val MAE: 1.491
# Epoch 29/50 - Train MSE: 4.807 - Val MSE: 7.626 - Val MAE: 1.537
# Epoch 30/50 - Train MSE: 2.217 - Val MSE: 11.326 - Val MAE: 1.651
# Epoch 31/50 - Train MSE: 2.782 - Val MSE: 10.698 - Val MAE: 1.648
# Epoch 32/50 - Train MSE: 1.659 - Val MSE: 8.794 - Val MAE: 1.526
# Epoch 33/50 - Train MSE: 7.500 - Val MSE: 8.133 - Val MAE: 1.508
# Epoch 34/50 - Train MSE: 2.808 - Val MSE: 8.535 - Val MAE: 1.566
# Epoch 35/50 - Train MSE: 3.191 - Val MSE: 9.341 - Val MAE: 1.578
# Epoch 36/50 - Train MSE: 1.467 - Val MSE: 8.457 - Val MAE: 1.513
# Epoch 37/50 - Train MSE: 5.448 - Val MSE: 8.437 - Val MAE: 1.568
# Epoch 38/50 - Train MSE: 2.873 - Val MSE: 8.760 - Val MAE: 1.538
# Epoch 39/50 - Train MSE: 0.913 - Val MSE: 9.062 - Val MAE: 1.563
# Epoch 40/50 - Train MSE: 0.724 - Val MSE: 8.225 - Val MAE: 1.518
# Epoch 41/50 - Train MSE: 1.246 - Val MSE: 8.071 - Val MAE: 1.535
# Epoch 42/50 - Train MSE: 5.115 - Val MSE: 8.439 - Val MAE: 1.497
# Epoch 43/50 - Train MSE: 2.425 - Val MSE: 7.698 - Val MAE: 1.473
# Epoch 44/50 - Train MSE: 2.887 - Val MSE: 8.294 - Val MAE: 1.516
# Epoch 45/50 - Train MSE: 2.087 - Val MSE: 8.345 - Val MAE: 1.510
# Epoch 46/50 - Train MSE: 2.436 - Val MSE: 7.995 - Val MAE: 1.529
# Epoch 47/50 - Train MSE: 1.208 - Val MSE: 7.793 - Val MAE: 1.555
# Epoch 48/50 - Train MSE: 5.545 - Val MSE: 9.069 - Val MAE: 1.517
# Epoch 49/50 - Train MSE: 1.018 - Val MSE: 8.951 - Val MAE: 1.554
# Epoch 50/50 - Train MSE: 2.787 - Val MSE: 9.191 - Val MAE: 1.559

# %%
#MSE
plt.figure()
plt.plot(train_mse_list, label="Train MSE")
plt.plot(val_mse_list, label="Val MSE")
plt.xlabel("Epoch")
plt.ylabel("Error")
plt.title("Training and Validation MSE (ResNet)")
plt.legend()
plt.show()

#MAE
plt.figure()
plt.plot(val_mae_list, label="Val MAE")
plt.xlabel("Epoch")
plt.ylabel("Error")
plt.title("Validation MAE (ResNet)")
plt.legend()
plt.show()
