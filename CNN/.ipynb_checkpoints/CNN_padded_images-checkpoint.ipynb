# %%
import sys
sys.path.append("../dataloaders")

# %%
import torch
import torch.nn as nn
import torch.optim as optim
from data_loader_cropping_padding import CroppedPaddedDataset
from torch.utils.data import random_split, DataLoader
import matplotlib.pyplot as plt

# %%
dataset = CroppedPaddedDataset("../labels.csv", "../images")
# Out:
# Image width 400 and height 200
# Found 402 valid samples

# %%
class CNNRegressor(nn.Module):
    def __init__(self):
        super().__init__()
        self.features = nn.Sequential(
            nn.Conv2d(3, 16, 3, padding=1),
            nn.ReLU(),
            nn.MaxPool2d(2),
            
            nn.Conv2d(16, 32, 3, padding=1),
            nn.ReLU(),
            nn.MaxPool2d(2),
        )
        self.gap = nn.AdaptiveAvgPool2d((1, 1))
        self.regressor = nn.Sequential(
            nn.Flatten(),
            nn.Linear(32, 1)  
        )

    def forward(self, x):
        x = self.features(x)
        x = self.gap(x)
        x = self.regressor(x)
        return x

# %%
#Training and validation data
val_split = 0.2  
n_total = len(dataset)
n_val = int(n_total * val_split)
n_train = n_total - n_val

train_set, val_set = random_split(dataset, [n_train, n_val])

train_loader = DataLoader(train_set, batch_size=32, shuffle=True)
val_loader = DataLoader(val_set, batch_size=32, shuffle=False)

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print("Using device:", device)

model = CNNRegressor().to(device)
criterion = nn.MSELoss()
optimizer = optim.SGD(model.parameters(), lr=0.01, momentum=0.9, weight_decay=1e-4)
# Out:
# Using device: cpu

# %%
num_epochs = 10 
train_mse_list = []
val_mse_list = []
val_mae_list = []

for epoch in range(num_epochs):
    #Training
    model.train()
    running_loss = 0.0
    n = 0

    for imgs, labels, names in train_loader:   
        imgs = imgs.to(device)
        labels = labels.float().view(-1, 1).to(device)

        optimizer.zero_grad()
        outputs = model(imgs)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()

        batch_size = imgs.size(0)
        running_loss += loss.item() * imgs.size(0)
        n += batch_size

    print(f"Epoch {epoch+1}/{num_epochs} - Train MSE: {running_loss / n:.4f}")

    #Validation
    model.eval()
    val_loss = 0.0
    val_mae = 0.0
    n_val = 0

    with torch.no_grad():
        for imgs, labels, names in val_loader:
            imgs = imgs.to(device)
            labels = labels.float().view(-1, 1).to(device)

            outputs = model(imgs)

            #MSE 
            loss = criterion(outputs, labels)
            val_loss += loss.item() * imgs.size(0)

            #MAE 
            val_mae += torch.abs(outputs - labels).sum().item()

            n_val += imgs.size(0)

    train_mse = running_loss / n
    val_mse = val_loss / n_val
    val_mae_epoch = val_mae / n_val

    train_mse_list.append(train_mse)
    val_mse_list.append(val_mse)
    val_mae_list.append(val_mae_epoch)

    print(f"Val MSE: {val_loss / n_val:.4f} | Val MAE: {val_mae / n_val:.4f}")
# Out:
# Epoch 1/100 - Train MSE: 51.4264
# Val MSE: 47.9140 | Val MAE: 3.7907
# Epoch 2/100 - Train MSE: 33.4160
# Val MSE: 41.5251 | Val MAE: 4.5111
# Epoch 3/100 - Train MSE: 32.2542
# Val MSE: 40.6375 | Val MAE: 4.1627
# Epoch 4/100 - Train MSE: 31.9292
# Val MSE: 41.5708 | Val MAE: 3.8689
# Epoch 5/100 - Train MSE: 31.5688
# Val MSE: 40.7660 | Val MAE: 4.0511
# Epoch 6/100 - Train MSE: 31.2910
# Val MSE: 40.6378 | Val MAE: 4.1658
# Epoch 7/100 - Train MSE: 31.4149
# Val MSE: 40.7338 | Val MAE: 4.0656
# Epoch 8/100 - Train MSE: 31.3667
# Val MSE: 41.0140 | Val MAE: 3.9746
# Epoch 9/100 - Train MSE: 31.5971
# Val MSE: 41.0054 | Val MAE: 3.9768
# Epoch 10/100 - Train MSE: 31.1989
# Val MSE: 40.6447 | Val MAE: 4.1900
# Epoch 11/100 - Train MSE: 31.6907
# Val MSE: 40.6778 | Val MAE: 4.2333
# Epoch 12/100 - Train MSE: 31.4779
# Val MSE: 40.6871 | Val MAE: 4.0919
# Epoch 13/100 - Train MSE: 31.3784
# Val MSE: 41.0849 | Val MAE: 3.9580
# Epoch 14/100 - Train MSE: 31.5632
# Val MSE: 40.8471 | Val MAE: 4.0214
# Epoch 15/100 - Train MSE: 31.6314
# Val MSE: 40.9909 | Val MAE: 4.3808
# Epoch 16/100 - Train MSE: 31.7666
# Val MSE: 40.6454 | Val MAE: 4.1318
# Epoch 17/100 - Train MSE: 31.2918
# Val MSE: 40.9958 | Val MAE: 3.9791
# Epoch 18/100 - Train MSE: 31.5508
# Val MSE: 41.3177 | Val MAE: 3.9113
# Epoch 19/100 - Train MSE: 31.6271
# Val MSE: 40.7321 | Val MAE: 4.0664
# Epoch 20/100 - Train MSE: 31.3424
# Val MSE: 40.9016 | Val MAE: 4.0045
# Epoch 21/100 - Train MSE: 31.4117
# Val MSE: 40.9918 | Val MAE: 3.9801
# Epoch 22/100 - Train MSE: 31.3400
# Val MSE: 40.6730 | Val MAE: 4.1021
# Epoch 23/100 - Train MSE: 31.4101
# Val MSE: 40.7854 | Val MAE: 4.0433
# Epoch 24/100 - Train MSE: 31.3891
# Val MSE: 40.6374 | Val MAE: 4.1565
# Epoch 25/100 - Train MSE: 31.3342
# Val MSE: 40.7343 | Val MAE: 4.0654
# Epoch 26/100 - Train MSE: 31.3675
# Val MSE: 40.7820 | Val MAE: 4.0447
# Epoch 27/100 - Train MSE: 31.3355
# Val MSE: 41.0701 | Val MAE: 3.9614
# Epoch 28/100 - Train MSE: 31.4418
# Val MSE: 40.7556 | Val MAE: 4.0556
# Epoch 29/100 - Train MSE: 31.3885
# Val MSE: 40.6452 | Val MAE: 4.1910
# Epoch 30/100 - Train MSE: 31.4538
# Val MSE: 40.6651 | Val MAE: 4.1088
# Epoch 31/100 - Train MSE: 31.3761
# Val MSE: 40.6406 | Val MAE: 4.1415
# Epoch 32/100 - Train MSE: 31.3635
# Val MSE: 40.7405 | Val MAE: 4.0624
# Epoch 33/100 - Train MSE: 31.3265
# Val MSE: 40.7012 | Val MAE: 4.0829
# Epoch 34/100 - Train MSE: 31.2998
# Val MSE: 40.9331 | Val MAE: 3.9956
# Epoch 35/100 - Train MSE: 31.5124
# Val MSE: 40.8474 | Val MAE: 4.0212
# Epoch 36/100 - Train MSE: 31.3902
# Val MSE: 40.6640 | Val MAE: 4.1098
# Epoch 37/100 - Train MSE: 31.3127
# Val MSE: 40.8307 | Val MAE: 4.0268
# Epoch 38/100 - Train MSE: 31.4190
# Val MSE: 40.9051 | Val MAE: 4.0035
# Epoch 39/100 - Train MSE: 31.4590
# Val MSE: 40.6427 | Val MAE: 4.1368
# Epoch 40/100 - Train MSE: 31.3908
# Val MSE: 40.6689 | Val MAE: 4.1054
# Epoch 41/100 - Train MSE: 31.4383
# Val MSE: 41.0150 | Val MAE: 3.9744
# Epoch 42/100 - Train MSE: 31.5416
# Val MSE: 41.0559 | Val MAE: 3.9647
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[48], line 19
#      17 outputs = model(imgs)
#      18 loss = criterion(outputs, labels)
# ---> 19 loss.backward()
#      20 optimizer.step()
#      22 batch_size = imgs.size(0)
#
# File ~\AppData\Roaming\Python\Python312\site-packages\torch\_tensor.py:581, in Tensor.backward(self, gradient, retain_graph, create_graph, inputs)
#     571 if has_torch_function_unary(self):
#     572     return handle_torch_function(
#     573         Tensor.backward,
#     574         (self,),
#    (...)
#     579         inputs=inputs,
#     580     )
# --> 581 torch.autograd.backward(
#     582     self, gradient, retain_graph, create_graph, inputs=inputs
#     583 )
#
# File ~\AppData\Roaming\Python\Python312\site-packages\torch\autograd\__init__.py:347, in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables, inputs)
#     342     retain_graph = create_graph
#     344 # The reason we repeat the same comment below is that
#     345 # some Python versions print out the first line of a multi-line function
#     346 # calls in the traceback and some print out the last line
# --> 347 _engine_run_backward(
#     348     tensors,
#     349     grad_tensors_,
#     350     retain_graph,
#     351     create_graph,
#     352     inputs,
#     353     allow_unreachable=True,
#     354     accumulate_grad=True,
#     355 )
#
# File ~\AppData\Roaming\Python\Python312\site-packages\torch\autograd\graph.py:825, in _engine_run_backward(t_outputs, *args, **kwargs)
#     823     unregister_hooks = _register_logging_hooks_on_whole_graph(t_outputs)
#     824 try:
# --> 825     return Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
#     826         t_outputs, *args, **kwargs
#     827     )  # Calls into the C++ engine to run the backward pass
#     828 finally:
#     829     if attach_logging_hooks:
#
# KeyboardInterrupt:

# %%
epochs = range(1, num_epochs + 1)

plt.plot(epochs, train_mse_list, label='Train MSE')
plt.plot(epochs, val_mse_list, label='Val MSE')
#plt.plot(epochs, val_mae_list, label='Val MAE')
plt.xlabel('Epoch')
plt.ylabel('Error')
plt.legend()
plt.title('Training and Validation Metrics')
plt.show()
