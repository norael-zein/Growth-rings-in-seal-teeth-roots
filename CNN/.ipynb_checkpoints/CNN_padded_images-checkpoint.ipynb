# %%
sys.path.append("../dataloaders")

# %%
import torch
import torch.nn as nn
import torch.optim as optim
import torchvision.models as models
from torchvision.models import ResNet18_Weights
from data_loader_cropping_padding import CroppedPaddedDataset
from torch.utils.data import random_split, DataLoader
import matplotlib.pyplot as plt
import sys

# %%
dataset = CroppedPaddedDataset("../labels.csv", "../images")
# Out:
# Image width 400 and height 200
# Found 402 valid samples

# %%
class CNNRegressor(nn.Module):
    def __init__(self):
        super().__init__()
        self.features = nn.Sequential(
            nn.Conv2d(3, 16, 3, padding=1),
            nn.ReLU(),
            nn.MaxPool2d(2),

            nn.Conv2d(16, 32, 3, padding=1),
            nn.ReLU(),
            nn.MaxPool2d(2),

            nn.Conv2d(32, 64, 3, padding=1),  
            nn.ReLU(),
            nn.MaxPool2d(2),
        )
        self.gap = nn.AdaptiveAvgPool2d((1, 1))
        self.regressor = nn.Sequential(
            nn.Flatten(),
            nn.Dropout(0.1),        
            nn.Linear(64, 32),
            nn.ReLU(),
            nn.Linear(32, 1),
        )

    def forward(self, x):
        x = self.features(x)
        x = self.gap(x)
        x = self.regressor(x)
        return x

# %%
#Training and validation data
val_split = 0.2  
n_total = len(dataset)
n_val = int(n_total * val_split)
n_train = n_total - n_val

train_set, val_set = random_split(dataset, [n_train, n_val])

train_loader = DataLoader(train_set, batch_size=32, shuffle=True)
val_loader = DataLoader(val_set, batch_size=32, shuffle=False)

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print("Using device:", device)

model = CNNRegressor().to(device)
criterion = nn.MSELoss()
optimizer = optim.Adam(model.parameters(), lr=5e-4, weight_decay=1e-4)
# Out:
# Using device: cpu

# %%
num_epochs = 50
train_mse_list = []
val_mse_list = []
val_mae_list = []

for epoch in range(num_epochs):
    #Training
    model.train()
    running_loss = 0.0
    n = 0

    for imgs, labels, names in train_loader:   
        imgs = imgs.to(device)
        labels = labels.float().view(-1, 1).to(device)

        optimizer.zero_grad()
        outputs = model(imgs)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()

        batch_size = imgs.size(0)
        running_loss += loss.item() * imgs.size(0)
        n += batch_size

    print(f"Epoch {epoch+1}/{num_epochs} - Train MSE: {running_loss / n:.4f}")

    #Validation
    model.eval()
    val_loss = 0.0
    val_mae = 0.0
    n_val = 0

    with torch.no_grad():
        for imgs, labels, names in val_loader:
            imgs = imgs.to(device)
            labels = labels.float().view(-1, 1).to(device)

            outputs = model(imgs)

            #MSE 
            loss = criterion(outputs, labels)
            val_loss += loss.item() * imgs.size(0)

            #MAE 
            val_mae += torch.abs(outputs - labels).sum().item()

            n_val += imgs.size(0)

    train_mse = running_loss / n
    val_mse = val_loss / n_val
    val_mae_epoch = val_mae / n_val

    train_mse_list.append(train_mse)
    val_mse_list.append(val_mse)
    val_mae_list.append(val_mae_epoch)

    print(f"Val MSE: {val_loss / n_val:.4f} | Val MAE: {val_mae / n_val:.4f}")
# Out:
# Epoch 1/50 - Train MSE: 53.7419
# Val MSE: 105.4333 | Val MAE: 6.5827
# Epoch 2/50 - Train MSE: 51.0465
# Val MSE: 98.1730 | Val MAE: 6.0775
# Epoch 3/50 - Train MSE: 42.8304
# Val MSE: 76.2486 | Val MAE: 4.6556
# Epoch 4/50 - Train MSE: 25.9529
# Val MSE: 51.1236 | Val MAE: 4.5524
# Epoch 5/50 - Train MSE: 22.9726
# Val MSE: 52.7326 | Val MAE: 4.3496
# Epoch 6/50 - Train MSE: 22.6572
# Val MSE: 53.6908 | Val MAE: 4.2956
# Epoch 7/50 - Train MSE: 22.5598
# Val MSE: 53.1222 | Val MAE: 4.3013
# Epoch 8/50 - Train MSE: 21.9859
# Val MSE: 52.3321 | Val MAE: 4.3265
# Epoch 9/50 - Train MSE: 22.1141
# Val MSE: 53.3027 | Val MAE: 4.2579
# Epoch 10/50 - Train MSE: 21.6907
# Val MSE: 52.2168 | Val MAE: 4.2662
# Epoch 11/50 - Train MSE: 22.4969
# Val MSE: 50.7064 | Val MAE: 4.3554
# Epoch 12/50 - Train MSE: 22.6065
# Val MSE: 51.2428 | Val MAE: 4.2817
# Epoch 13/50 - Train MSE: 22.2387
# Val MSE: 55.6430 | Val MAE: 4.1571
# Epoch 14/50 - Train MSE: 22.6377
# Val MSE: 53.9736 | Val MAE: 4.1790
# Epoch 15/50 - Train MSE: 21.9578
# Val MSE: 52.2479 | Val MAE: 4.2004
# Epoch 16/50 - Train MSE: 21.6439
# Val MSE: 52.4311 | Val MAE: 4.1852
# Epoch 17/50 - Train MSE: 21.5667
# Val MSE: 52.3296 | Val MAE: 4.1731
# Epoch 18/50 - Train MSE: 21.6346
# Val MSE: 50.5433 | Val MAE: 4.2341
# Epoch 19/50 - Train MSE: 22.5619
# Val MSE: 53.6049 | Val MAE: 4.1262
# Epoch 20/50 - Train MSE: 22.1371
# Val MSE: 48.7978 | Val MAE: 4.3803
# Epoch 21/50 - Train MSE: 21.4752
# Val MSE: 52.5677 | Val MAE: 4.0997
# Epoch 22/50 - Train MSE: 21.3680
# Val MSE: 51.1079 | Val MAE: 4.1178
# Epoch 23/50 - Train MSE: 21.5379
# Val MSE: 50.0538 | Val MAE: 4.1329
# Epoch 24/50 - Train MSE: 21.0906
# Val MSE: 50.2122 | Val MAE: 4.0906
# Epoch 25/50 - Train MSE: 21.0994
# Val MSE: 49.6919 | Val MAE: 4.0855
# Epoch 26/50 - Train MSE: 20.8544
# Val MSE: 49.7188 | Val MAE: 4.0448
# Epoch 27/50 - Train MSE: 21.4031
# Val MSE: 50.0092 | Val MAE: 4.0096
# Epoch 28/50 - Train MSE: 20.6059
# Val MSE: 47.6003 | Val MAE: 4.1317
# Epoch 29/50 - Train MSE: 20.2493
# Val MSE: 50.1003 | Val MAE: 3.9593
# Epoch 30/50 - Train MSE: 20.6447
# Val MSE: 48.5578 | Val MAE: 3.9995
# Epoch 31/50 - Train MSE: 19.7209
# Val MSE: 48.5170 | Val MAE: 3.9807
# Epoch 32/50 - Train MSE: 20.1850
# Val MSE: 48.9722 | Val MAE: 3.9335
# Epoch 33/50 - Train MSE: 19.6700
# Val MSE: 49.0751 | Val MAE: 3.8831
# Epoch 34/50 - Train MSE: 20.1707
# Val MSE: 47.3330 | Val MAE: 3.9696
# Epoch 35/50 - Train MSE: 19.3757
# Val MSE: 47.6351 | Val MAE: 3.9125
# Epoch 36/50 - Train MSE: 19.4168
# Val MSE: 47.8422 | Val MAE: 3.8576
# Epoch 37/50 - Train MSE: 20.2889
# Val MSE: 48.7739 | Val MAE: 3.7739
# Epoch 38/50 - Train MSE: 19.9367
# Val MSE: 47.6205 | Val MAE: 3.8522
# Epoch 39/50 - Train MSE: 19.0041
# Val MSE: 44.8887 | Val MAE: 3.9795
# Epoch 40/50 - Train MSE: 19.6003
# Val MSE: 49.0558 | Val MAE: 3.7177
# Epoch 41/50 - Train MSE: 17.8862
# Val MSE: 44.6706 | Val MAE: 3.8183
# Epoch 42/50 - Train MSE: 18.3809
# Val MSE: 47.1826 | Val MAE: 3.5818
# Epoch 43/50 - Train MSE: 18.0338
# Val MSE: 43.9484 | Val MAE: 3.6937
# Epoch 44/50 - Train MSE: 17.5119
# Val MSE: 46.9560 | Val MAE: 3.5217
# Epoch 45/50 - Train MSE: 17.0053
# Val MSE: 42.0907 | Val MAE: 3.7256
# Epoch 46/50 - Train MSE: 17.4786
# Val MSE: 43.8985 | Val MAE: 3.5343
# Epoch 47/50 - Train MSE: 16.8455
# Val MSE: 49.4281 | Val MAE: 3.4888
# Epoch 48/50 - Train MSE: 17.4868
# Val MSE: 41.9597 | Val MAE: 3.9064
# Epoch 49/50 - Train MSE: 18.6885
# Val MSE: 44.9714 | Val MAE: 3.4836
# Epoch 50/50 - Train MSE: 17.1895
# Val MSE: 44.6991 | Val MAE: 3.5291

# %%
epochs = range(1, num_epochs + 1)

plt.plot(epochs, train_mse_list, label='Train MSE')
plt.plot(epochs, val_mse_list, label='Val MSE')
plt.xlabel('Epoch')
plt.ylabel('Error')
plt.legend()
plt.title('Training and Validation MSE')
plt.show()

# %%
epochs = range(1, num_epochs + 1)

plt.plot(epochs, val_mae_list, label='Val MAE')
plt.xlabel('Epoch')
plt.ylabel('Error')
plt.legend()
plt.title('Validation MAE')
plt.show()

# %%
class ResNetRegressor(nn.Module):
    def __init__(self):
        super().__init__()
        #Resnet18
        self.backbone = models.resnet18(weights=ResNet18_Weights.DEFAULT)
        
        #Last layer with regression
        in_features = self.backbone.fc.in_features
        self.backbone.fc = nn.Linear(in_features, 1)

    def forward(self, x):
        return self.backbone(x)

model = ResNetRegressor().to(device)

# %%
criterion = nn.SmoothL1Loss(beta=1.0)  #Huber-loss

optimizer = optim.Adam(model.parameters(), lr=1e-4, weight_decay=1e-4)

scheduler = optim.lr_scheduler.ReduceLROnPlateau(
    optimizer, mode='min', factor=0.5, patience=5, verbose=True
)

num_epochs = 50  

train_mse_list = []
val_mse_list = []
val_mae_list = []
# Out:
# C:\Users\norae\AppData\Roaming\Python\Python312\site-packages\torch\optim\lr_scheduler.py:62: UserWarning: The verbose parameter is deprecated. Please use get_last_lr() to access the learning rate.
#   warnings.warn(

# %%
#Train ResNet regressor

#Early stopping
best_val_mae = float("inf")            
best_state_dict = None                

for epoch in range(num_epochs):
    #Train
    model.train()
    running_mse = 0.0
    n_train = 0

    for imgs, labels, names in train_loader:
        imgs = imgs.to(device)
        labels = labels.float().view(-1, 1).to(device)

        optimizer.zero_grad()
        outputs = model(imgs)

        loss = criterion(outputs, labels)   #SmoothL1Loss
        loss.backward()
        optimizer.step()

        #MSE
        mse_batch = torch.mean((outputs - labels) ** 2).item()
        batch_size = imgs.size(0)
        running_mse += mse_batch * batch_size
        n_train += batch_size

    train_mse_epoch = running_mse / n_train
    train_mse_list.append(train_mse_epoch)

    #Validation
    model.eval()
    val_mse = 0.0
    val_mae = 0.0
    n_val = 0

    with torch.no_grad():
        for imgs, labels, names in val_loader:
            imgs = imgs.to(device)
            labels = labels.float().view(-1, 1).to(device)

            outputs = model(imgs)

            mse_batch = torch.mean((outputs - labels) ** 2).item()
            mae_batch = torch.mean(torch.abs(outputs - labels)).item()
            batch_size = imgs.size(0)

            val_mse += mse_batch * batch_size
            val_mae += mae_batch * batch_size
            n_val += batch_size

    val_mse_epoch = val_mse / n_val
    val_mae_epoch = val_mae / n_val

    val_mse_list.append(val_mse_epoch)
    val_mae_list.append(val_mae_epoch)

    scheduler.step(val_mae_epoch)

    #Early stopping
    if val_mae_epoch < best_val_mae:          
        best_val_mae = val_mae_epoch
        best_state_dict = model.state_dict().copy()
        print(f"New best model saved at epoch {epoch+1}! Val MAE = {best_val_mae:.3f}")

    print(
        f"Epoch {epoch+1}/{num_epochs} - "
        f"Train MSE: {train_mse_epoch:.3f} - "
        f"Val MSE: {val_mse_epoch:.3f} - "
        f"Val MAE: {val_mae_epoch:.3f}"
    )

#Load best model after early stopping
model.load_state_dict(best_state_dict)     
print(f"\n Best model with Val MAE = {best_val_mae:.3f}")
# Out:
# New best model saved at epoch 1! Val MAE = 7.022
# Epoch 1/50 - Train MSE: 45.689 - Val MSE: 104.822 - Val MAE: 7.022
# New best model saved at epoch 2! Val MAE = 4.884
# Epoch 2/50 - Train MSE: 29.383 - Val MSE: 76.467 - Val MAE: 4.884
# New best model saved at epoch 3! Val MAE = 4.049
# Epoch 3/50 - Train MSE: 17.985 - Val MSE: 60.638 - Val MAE: 4.049
# Epoch 4/50 - Train MSE: 13.973 - Val MSE: 63.973 - Val MAE: 4.629
# New best model saved at epoch 5! Val MAE = 3.065
# Epoch 5/50 - Train MSE: 11.986 - Val MSE: 48.119 - Val MAE: 3.065
# Epoch 6/50 - Train MSE: 9.992 - Val MSE: 45.958 - Val MAE: 3.146
# New best model saved at epoch 7! Val MAE = 2.522
# Epoch 7/50 - Train MSE: 8.525 - Val MSE: 39.172 - Val MAE: 2.522
# Epoch 8/50 - Train MSE: 7.290 - Val MSE: 42.324 - Val MAE: 2.899
# New best model saved at epoch 9! Val MAE = 2.271
# Epoch 9/50 - Train MSE: 7.151 - Val MSE: 35.963 - Val MAE: 2.271
# New best model saved at epoch 10! Val MAE = 2.217
# Epoch 10/50 - Train MSE: 5.893 - Val MSE: 36.772 - Val MAE: 2.217
# New best model saved at epoch 11! Val MAE = 2.158
# Epoch 11/50 - Train MSE: 5.411 - Val MSE: 32.972 - Val MAE: 2.158
# New best model saved at epoch 12! Val MAE = 2.053
# Epoch 12/50 - Train MSE: 4.540 - Val MSE: 26.098 - Val MAE: 2.053
# Epoch 13/50 - Train MSE: 3.882 - Val MSE: 33.810 - Val MAE: 2.249
# Epoch 14/50 - Train MSE: 4.698 - Val MSE: 30.409 - Val MAE: 2.172
# Epoch 15/50 - Train MSE: 4.148 - Val MSE: 37.778 - Val MAE: 2.326
# Epoch 16/50 - Train MSE: 4.337 - Val MSE: 33.164 - Val MAE: 2.207
# Epoch 17/50 - Train MSE: 3.764 - Val MSE: 27.750 - Val MAE: 2.272
# Epoch 18/50 - Train MSE: 5.001 - Val MSE: 24.394 - Val MAE: 2.221
# Epoch 19/50 - Train MSE: 3.872 - Val MSE: 24.845 - Val MAE: 2.059
# New best model saved at epoch 20! Val MAE = 2.040
# Epoch 20/50 - Train MSE: 2.834 - Val MSE: 25.220 - Val MAE: 2.040
# New best model saved at epoch 21! Val MAE = 1.946
# Epoch 21/50 - Train MSE: 2.752 - Val MSE: 21.299 - Val MAE: 1.946
# New best model saved at epoch 22! Val MAE = 1.806
# Epoch 22/50 - Train MSE: 2.452 - Val MSE: 21.059 - Val MAE: 1.806
# Epoch 23/50 - Train MSE: 2.909 - Val MSE: 21.436 - Val MAE: 1.883
# Epoch 24/50 - Train MSE: 2.671 - Val MSE: 24.490 - Val MAE: 1.946
# New best model saved at epoch 25! Val MAE = 1.732
# Epoch 25/50 - Train MSE: 2.005 - Val MSE: 15.352 - Val MAE: 1.732
# New best model saved at epoch 26! Val MAE = 1.500
# Epoch 26/50 - Train MSE: 1.117 - Val MSE: 8.392 - Val MAE: 1.500
# Epoch 27/50 - Train MSE: 2.105 - Val MSE: 11.570 - Val MAE: 1.725
# Epoch 28/50 - Train MSE: 1.682 - Val MSE: 10.868 - Val MAE: 1.563
# Epoch 29/50 - Train MSE: 1.951 - Val MSE: 19.482 - Val MAE: 1.861
# Epoch 30/50 - Train MSE: 2.339 - Val MSE: 22.261 - Val MAE: 1.946
# Epoch 31/50 - Train MSE: 2.405 - Val MSE: 23.548 - Val MAE: 1.944
# Epoch 32/50 - Train MSE: 1.800 - Val MSE: 20.013 - Val MAE: 1.807
# Epoch 33/50 - Train MSE: 1.898 - Val MSE: 20.703 - Val MAE: 1.830
# Epoch 34/50 - Train MSE: 1.383 - Val MSE: 15.142 - Val MAE: 1.673
# Epoch 35/50 - Train MSE: 1.891 - Val MSE: 13.689 - Val MAE: 1.638
# Epoch 36/50 - Train MSE: 1.707 - Val MSE: 14.038 - Val MAE: 1.597
# Epoch 37/50 - Train MSE: 1.744 - Val MSE: 13.054 - Val MAE: 1.640
# Epoch 38/50 - Train MSE: 1.339 - Val MSE: 15.628 - Val MAE: 1.714
# Epoch 39/50 - Train MSE: 2.083 - Val MSE: 13.940 - Val MAE: 1.649
# Epoch 40/50 - Train MSE: 1.067 - Val MSE: 14.487 - Val MAE: 1.682
# Epoch 41/50 - Train MSE: 2.224 - Val MSE: 15.335 - Val MAE: 1.685
# Epoch 42/50 - Train MSE: 1.969 - Val MSE: 17.670 - Val MAE: 1.742
# Epoch 43/50 - Train MSE: 1.529 - Val MSE: 17.479 - Val MAE: 1.735
# Epoch 44/50 - Train MSE: 1.811 - Val MSE: 14.585 - Val MAE: 1.691
# Epoch 45/50 - Train MSE: 1.605 - Val MSE: 15.618 - Val MAE: 1.689
# Epoch 46/50 - Train MSE: 1.673 - Val MSE: 14.347 - Val MAE: 1.639
# Epoch 47/50 - Train MSE: 1.905 - Val MSE: 14.298 - Val MAE: 1.654
# Epoch 48/50 - Train MSE: 1.748 - Val MSE: 15.245 - Val MAE: 1.674
# Epoch 49/50 - Train MSE: 2.342 - Val MSE: 18.909 - Val MAE: 1.846
# Epoch 50/50 - Train MSE: 1.836 - Val MSE: 15.143 - Val MAE: 1.678
#
#  Best model with Val MAE = 1.500

# %%
#MSE
plt.figure()
plt.plot(train_mse_list, label="Train MSE")
plt.plot(val_mse_list, label="Val MSE")
plt.xlabel("Epoch")
plt.ylabel("Error")
plt.title("Training and Validation MSE (ResNet)")
plt.legend()
plt.show()

#MAE
plt.figure()
plt.plot(val_mae_list, label="Val MAE")
plt.xlabel("Epoch")
plt.ylabel("Error")
plt.title("Validation MAE (ResNet)")
plt.legend()
plt.show()
